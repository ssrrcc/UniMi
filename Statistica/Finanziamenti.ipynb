# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

fin = pd.read_csv('finanziamenti.csv', sep=';',decimal=',')
fin
# Out:
#         id  TemaPrioritario                                       FONTE  \
# 0        4                5                      Compet. per le imprese
# 1       38                5                      Compet. per le imprese
# 2       39               11                             Agenda digitale
# 3       43                4                       Ricerca e innovazione
# 4       73                6                       Ricerca e innovazione
# 5      106                6                       Ricerca e innovazione
# 6      160                5                      Compet. per le imprese
# 7      163                6                       Ricerca e innovazione
# 8      170                5                      Compet. per le imprese
# 9      218               11                             Agenda digitale
# 10     238               11                             Agenda digitale
# 11     251               11                             Agenda digitale
# ...

# %%
type(fin['CodiceCategoria'][0])
# Out:
# numpy.int64

# %%
freq_unita = pd.value_counts(fin['UNITA'])
freq_unita
# Out:
# PERUGIA                 1005
# TERNI                    638
# FOLIGNO                  449
# CITTA DI CASTELLO        288
# SLL NON ATTRIBUIBILE     255
# ASSISI                   243
# SPOLETO                  186
# UMBERTIDE                124
# TODI                     117
# GUBBIO                    76
# GUALDO TADINO             75
# CASTIGLIONE DEL L         75
# ORVIETO                   60
# CHIUSI                    30
# NORCIA                    28
# CASCIA                    13
# SLL MULTIPLO               5
# CORTONA                    1
# Name: UNITA, dtype: int64

# %%
freq_unita.plot.bar()
plt.show()

# %%
progetti_a = fin[fin['FinProvincia'] < fin['FinRegione']]
len(progetti_a)
# Out:
# 368

# %%
progetti_b = fin[fin['FinProvincia'] >= fin['FinRegione']]
len(progetti_b)
# Out:
# 3284

# %%
progetti_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 7 to 3665
# Data columns (total 9 columns):
# id                 368 non-null int64
# TemaPrioritario    368 non-null int64
# FONTE              368 non-null object
# CodiceCategoria    368 non-null int64
# CATEGORIA          368 non-null object
# UNITA              368 non-null object
# FinProvincia       368 non-null float64
# FinRegione         368 non-null float64
# TotSpese           133 non-null float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 28.8+ KB

# %%
selezione_progetti_a = progetti_a[progetti_a['FinProvincia'] < 1000]
selezione_progetti_a = selezione_progetti_a[selezione_progetti_a['FinProvincia'] >= 200]

# %%
selezione_progetti_a.plot.hist()
plt.show()

# %%
selezione_progetti_a.plot.box()
plt.show()
